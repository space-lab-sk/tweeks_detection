# %% [markdown]
# # Detekcia bleskov v rádiových spektrogramoch založená na konvolučných neurónových sieťach
#
# ## Príprava prostredia
#
# Príkazy na inštaláciu potrebných knižníc.

# %%
# !pip install PyPDF2
# !pip install pdf2image
# !pip install os-sys
# !pip install temp
# !conda install -c conda-forge poppler -y
# !pip install zipfile38
# !pip install pycopy-fnmatch
# !pip install python-csv
# !pip install pandas
# !pip install numpy
# !pip install jsonlib
# !pip install python-math
# !pip install opencv-python
# !pip install Pillow

# %% [markdown]
# Import potrebných knižníc.

# %%
import PyPDF2
import os
import tempfile
import zipfile,fnmatch
import csv
import pandas as pd
import numpy as np
import json
import math 
import cv2
from PIL import Image, ImageDraw
import operator
from skimage.io import imread
from PyPDF2 import PdfFileWriter, PdfFileReader
from pdf2image import convert_from_path, convert_from_bytes
from pdf2image.exceptions import (
    PDFInfoNotInstalledError,
    PDFPageCountError,
    PDFSyntaxError
)
from PIL import Image

# %% [markdown]
# ## Terminalový príkaz na stiahnutie obrázkov priamo zo servera UFA AV ČR
#
# Je potrebné url modifikovať na základe potreby.

# %%
wget -A zip -r -l 3 http://bleska.ufa.cas.cz/lsbb/storage/elm/2015

# %% [markdown]
# ## Rozbalenie a premazanie priečinkov stiahnutých dát
#
# ### Vstupy
#
# rootPath: cesta ku priečinku, ktorý obsahuje výstupy analyzátora stiahnuté zo servera UFA AV ČR

# %%
rootPath = r"files/zip_from_web_unpacked"

# %%
####### UNZIP
pattern = '*.zip'
for root, dirs, files in os.walk(rootPath):
    for filename in fnmatch.filter(files, pattern):
        zipfile.ZipFile(os.path.join(root, filename)).extractall(os.path.join(root, os.path.splitext(filename)[0]))
        os.remove(os.path.join(root, filename))

for root, dirs, files in os.walk(rootPath):
    for file in files:
        if file.endswith(".pdf")==False:
            os.remove(os.path.join(root, file))

# %% [markdown]
# ## Vytvorenie sprektrogramov ako vstupu pre neurónovú sieť
#
# ### Vstupy
# left: parameter vzdialenosti ľavej hrany spektrogramu od ľavej hrany obrázka, na ktorom sa spektrogram nachádza (v pixeloch)<br>
# upper: parameter vzdialenosti hornej hrany spektrogramu od hornej hrany obrázka, na ktorom sa spektrogram nachádza (v pixeloch)<br>
# right: parameter vzdialenosti pravej hrany spektrogramu od ľavej hrany obrázka, na ktorom sa spektrogram nachádza (v pixeloch)<br>
# lower: parameter vzdialenosti spodnej hrany spektrogramu od vrchnej hrany obrázka, na ktorom sa spektrogram nachádza (v pixeloch)<br>
# rootPath: cesta ku priečinku, ktorý obsahuje výstupy analyzátora stiahnuté rozbalené zo servera UFA AV ČR

# %%
left=154
upper=1392
right=1575
lower=1554

# %%
####### CROP
for root, dirs, files in os.walk(rootPath):
    pole=[]
    for file in files:
        if file.endswith(".pdf"):
            print("####################################")
            print("processing %s" %root)
            pole=[]
            pdfFileObj = open(os.path.join(root, file), 'rb')
            pdfReader = PyPDF2.PdfFileReader(pdfFileObj)
            pageObjDate = pdfReader.getPage(0)
            textDate=pageObjDate.extractText()
            if "from " in textDate:
                datum=textDate[textDate.find('from ')+5:textDate.find('from ')+29]
            else: 
                print("pdf from %s is empty, lets continue")
                break
            datum=datum.replace("-", "")
            datum=datum.replace("T", "_")
            datum=datum.replace(".", "_", 1)
            datum=datum.replace(".", "")
            datum=datum.replace(":", "")
            for j in range(pdfReader.numPages):
                pageObj = pdfReader.getPage(j)
                text=pageObj.extractText()
                if "Part" in text:
                    pole.append(text[text.find('Part')+5:text.find('/')])
                else:
                    pole.append(0)

            with tempfile.TemporaryDirectory() as path:
                images_from_path = convert_from_path(os.path.join(root, file), output_folder=path)

            i=0
            for page in images_from_path:
                page.save(os.path.join(root,"%s. %s.jpg" % (i, pole[i])), 'JPEG')   
                i+=1

            os.remove(os.path.join(root, "0. 0.jpg"))
            os.remove(os.path.join(root, "%s. %s.jpg" % (i-1, pole[i-1])))
            pole.remove(pole[0])
            pole.remove(pole[i-2])
            for i in pole:
                im = Image.open(os.path.join(root, "%s. %s.jpg" % (str(pole.index(i)+1), i)))
                im.crop((left, upper, right, lower)).save(os.path.join(root, "ch2_%s_s%s.jpg"%(datum, i)))
                os.remove(os.path.join(root, "%s. %s.jpg" % (str(pole.index(i)+1), i)))
            os.remove(os.path.join(root, "data.pdf"))
        else:
            continue
# Out:
# ####################################
# processing files/zip_from_web_unpacked/elm_20150515_200446_pics
# ####################################
# processing files/zip_from_web_unpacked/elm_20150515_220450_pics

# %% [markdown]
# ## Spustenie automatickej detekcie bleskov
#
# ### Vstupy
# detect.py: cesta k súboru detect.py<br>
# source: parameter obsahujúci cestu k priečinku, v ktorom je dataset obrázkov a textových súborov v jednom<br>
# weights: parameter obsahujúci cestu k váham, pomocou ktorých chceme detekciu vykonať<br>
# iou: hodnota thresholdu IoU<br>
# conf: hodnota confidence thresholdu<br>
# img: veľkosť obrázka, na ktorom bude trénovanie prebiehať v pixeloch<br>
# save-txt: parameter, na základe ktorého sa budú detaily detekcie ukladať aj do textových súborov<br>
# save-conf: parameter, na základe ktorého sa budú detaily confidence (istoty modelu) ukladať aj do textových súborov

# %%
# !python yolo/detect.py --source ./yolo/test_img --weights yolo/runs/train/exp17/weights/best.pt --iou 0.45 --conf 0.3 --img 1184 --save-txt --save-conf
# Out:
# Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.3, device='', exist_ok=False, hide_conf=False, hide_labels=False, img_size=1184, iou_thres=0.45, line_thickness=3, name='exp', nosave=False, project='runs/detect', save_conf=True, save_crop=False, save_txt=True, source='./yolo/test_img', update=False, view_img=False, weights=['yolo/runs/train/exp17/weights/best.pt'])
# requirements: /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/requirements.txt not found, check failed.
# YOLOv5 🚀 v5.0-97-gffb47ff torch 1.7.0 CUDA:0 (Quadro RTX 4000, 7982.3125MB)
#
# Fusing layers...
# Model Summary: 224 layers, 7056607 parameters, 0 gradients
# image 1/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20150902_230932_991_s93.jpg: 160x1184 11 Blesks, 4 Blesk s chvostikoms, Done. (0.019s)
# image 2/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20150902_231433_221_s109.jpg: 160x1184 17 Blesks, 2 Blesk s chvostikoms, Done. (0.017s)
# image 3/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20150902_231433_221_s44.jpg: 160x1184 9 Blesks, 1 Blesk s chvostikom, Done. (0.015s)
# image 4/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20150902_231433_221_s47.jpg: 160x1184 8 Blesks, 4 Blesk s chvostikoms, Done. (0.015s)
# image 5/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20150902_231433_221_s63.jpg: 160x1184 14 Blesks, 7 Blesk s chvostikoms, Done. (0.013s)
# image 6/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20150902_231433_221_s78.jpg: 160x1184 10 Blesks, 2 Blesk s chvostikoms, Done. (0.015s)
# image 7/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20150902_231433_221_s90.jpg: 160x1184 9 Blesks, 2 Blesk s chvostikoms, Done. (0.015s)
# image 8/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20150902_231933_448_s102.jpg: 160x1184 8 Blesks, 4 Blesk s chvostikoms, Done. (0.015s)
# image 9/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20150902_231933_448_s105.jpg: 160x1184 14 Blesks, 3 Blesk s chvostikoms, Done. (0.016s)
# image 10/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20150902_231933_448_s5.jpg: 160x1184 8 Blesks, 2 Blesk s chvostikoms, Done. (0.015s)
# image 11/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20150902_231933_448_s61.jpg: 160x1184 9 Blesks, 3 Blesk s chvostikoms, Done. (0.016s)
# image 12/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20150902_231933_448_s80.jpg: 160x1184 16 Blesks, 3 Blesk s chvostikoms, Done. (0.018s)
# image 13/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20150902_232433_673_s116.jpg: 160x1184 11 Blesks, 5 Blesk s chvostikoms, Done. (0.014s)
# image 14/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20150902_232433_673_s44.jpg: 160x1184 13 Blesks, 3 Blesk s chvostikoms, Done. (0.016s)
# image 15/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20150902_232433_673_s5.jpg: 160x1184 15 Blesks, 4 Blesk s chvostikoms, Done. (0.014s)
# image 16/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20150902_232433_673_s52.jpg: 160x1184 15 Blesks, 3 Blesk s chvostikoms, Done. (0.015s)
# image 17/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20150902_232933_901_s26.jpg: 160x1184 24 Blesks, 1 Blesk s chvostikom, Done. (0.016s)
# image 18/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20150902_232933_901_s58.jpg: 160x1184 15 Blesks, 2 Blesk s chvostikoms, Done. (0.014s)
# image 19/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20150902_232933_901_s68.jpg: 160x1184 16 Blesks, 2 Blesk s chvostikoms, Done. (0.015s)
# image 20/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20150902_233434_128_s24.jpg: 160x1184 7 Blesks, 2 Blesk s chvostikoms, Done. (0.016s)
# image 21/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20150902_233434_128_s66.jpg: 160x1184 19 Blesks, 3 Blesk s chvostikoms, Done. (0.014s)
# image 22/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20150902_233434_128_s79.jpg: 160x1184 3 Blesks, 4 Blesk s chvostikoms, Done. (0.014s)
# image 23/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20150902_233934_355_s140.jpg: 160x1184 18 Blesks, 2 Blesk s chvostikoms, Done. (0.014s)
# image 24/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20150902_234434_583_s8.jpg: 160x1184 14 Blesks, 1 Blesk s chvostikom, Done. (0.017s)
# image 25/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20150902_234934_811_s8.jpg: 160x1184 12 Blesks, 4 Blesk s chvostikoms, Done. (0.015s)
# image 26/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20150907_142436_601_s43.jpg: 160x1184 5 Blesks, Done. (0.016s)
# image 27/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20150907_142436_601_s54.jpg: 160x1184 10 Blesks, Done. (0.016s)
# image 28/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20150907_142436_601_s57.jpg: 160x1184 5 Blesks, Done. (0.016s)
# image 29/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20150907_142936_828_s135.jpg: 160x1184 13 Blesks, Done. (0.015s)
# image 30/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20150907_142936_828_s61.jpg: 160x1184 8 Blesks, Done. (0.015s)
# image 31/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20150907_144437_488_s132.jpg: 160x1184 15 Blesks, Done. (0.017s)
# image 32/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20150907_144437_488_s68.jpg: 160x1184 11 Blesks, Done. (0.014s)
# image 33/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20150907_144937_719_s58.jpg: 160x1184 18 Blesks, Done. (0.017s)
# image 34/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20150907_145437_948_s1.jpg: 160x1184 18 Blesks, Done. (0.016s)
# image 35/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20150907_145437_948_s104.jpg: 160x1184 10 Blesks, Done. (0.015s)
# image 36/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20150907_145437_948_s86.jpg: 160x1184 11 Blesks, Done. (0.015s)
# image 37/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20150907_145938_171_s119.jpg: 160x1184 13 Blesks, Done. (0.015s)
# image 38/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20150907_145938_171_s46.jpg: 160x1184 14 Blesks, Done. (0.015s)
# image 39/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20150907_145938_171_s82.jpg: 160x1184 10 Blesks, Done. (0.015s)
# image 40/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20150907_150438_397_s61.jpg: 160x1184 11 Blesks, Done. (0.016s)
# image 41/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20150907_150938_624_s140.jpg: 160x1184 17 Blesks, Done. (0.014s)
# image 42/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20150914_125211_333_s12.jpg: 160x1184 7 Blesks, Done. (0.015s)
# image 43/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20150914_130211_791_s23.jpg: 160x1184 18 Blesks, Done. (0.018s)
# image 44/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20150914_130211_791_s31.jpg: 160x1184 11 Blesks, Done. (0.015s)
# image 45/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20150914_130211_791_s4.jpg: 160x1184 17 Blesks, Done. (0.015s)
# image 46/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20150914_130211_791_s44.jpg: 160x1184 13 Blesks, Done. (0.017s)
# image 47/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20150914_131712_473_s89.jpg: 160x1184 14 Blesks, Done. (0.019s)
# image 48/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20150914_132212_691_s133.jpg: 160x1184 8 Blesks, Done. (0.014s)
# image 49/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20150914_132212_691_s38.jpg: 160x1184 15 Blesks, Done. (0.016s)
# image 50/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20150914_132212_691_s72.jpg: 160x1184 15 Blesks, Done. (0.016s)
# image 51/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20150914_132712_919_s8.jpg: 160x1184 15 Blesks, Done. (0.015s)
# image 52/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20150914_132712_919_s87.jpg: 160x1184 15 Blesks, Done. (0.014s)
# image 53/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20150914_133213_144_s29.jpg: 160x1184 13 Blesks, Done. (0.014s)
# image 54/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20150915_184833_399_s117.jpg: 160x1184 14 Blesks, 1 Blesk s chvostikom, Done. (0.016s)
# image 55/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20150915_184833_399_s98.jpg: 160x1184 13 Blesks, Done. (0.016s)
# image 56/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20150915_185833_856_s67.jpg: 160x1184 5 Blesks, 4 Blesk s chvostikoms, Done. (0.013s)
# image 57/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20150915_190834_313_s140.jpg: 160x1184 9 Blesks, Done. (0.014s)
# image 58/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20150915_192835_228_s90.jpg: 160x1184 10 Blesks, 1 Blesk s chvostikom, Done. (0.016s)
# image 59/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20150915_193335_458_s134.jpg: 160x1184 7 Blesks, 4 Blesk s chvostikoms, Done. (0.016s)
# image 60/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20150921_184010_496_s111.jpg: 160x1184 8 Blesks, 5 Blesk s chvostikoms, Done. (0.016s)
# image 61/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20150921_185511_185_s121.jpg: 160x1184 13 Blesks, 1 Blesk s chvostikom, Done. (0.015s)
# image 62/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20150921_191011_872_s75.jpg: 160x1184 10 Blesks, 3 Blesk s chvostikoms, Done. (0.016s)
# image 63/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20150921_192012_338_s21.jpg: 160x1184 12 Blesks, 3 Blesk s chvostikoms, Done. (0.015s)
# image 64/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20150927_133132_913_s134.jpg: 160x1184 6 Blesks, Done. (0.014s)
# image 65/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20150927_134133_388_s103.jpg: 160x1184 5 Blesks, Done. (0.015s)
# image 66/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20150927_134133_388_s110.jpg: 160x1184 11 Blesks, Done. (0.015s)
# image 67/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20150927_134133_388_s143.jpg: 160x1184 7 Blesks, Done. (0.015s)
# image 68/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20150927_134133_388_s43.jpg: 160x1184 11 Blesks, Done. (0.017s)
# image 69/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20150927_134133_388_s87.jpg: 160x1184 8 Blesks, Done. (0.016s)
# image 70/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20150927_134133_388_s92.jpg: 160x1184 6 Blesks, Done. (0.015s)
# image 71/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20150927_134633_618_s23.jpg: 160x1184 9 Blesks, Done. (0.015s)
# image 72/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20150927_135133_845_s91.jpg: 160x1184 8 Blesks, Done. (0.018s)
# image 73/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20150927_135133_845_s96.jpg: 160x1184 2 Blesks, Done. (0.015s)
# image 74/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20150927_135133_845_s97.jpg: 160x1184 5 Blesks, Done. (0.016s)
# image 75/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20150927_135634_076_s116.jpg: 160x1184 11 Blesks, Done. (0.015s)
# image 76/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20150927_135634_076_s38.jpg: 160x1184 8 Blesks, Done. (0.015s)
# image 77/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20150927_140134_305_s108.jpg: 160x1184 12 Blesks, Done. (0.014s)
# image 78/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20150927_140134_305_s133.jpg: 160x1184 12 Blesks, Done. (0.015s)
# image 79/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20150927_140134_305_s146.jpg: 160x1184 6 Blesks, Done. (0.015s)
# image 80/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20150927_140134_305_s27.jpg: 160x1184 11 Blesks, Done. (0.015s)
# image 81/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20150927_140634_533_s135.jpg: 160x1184 12 Blesks, Done. (0.016s)
# image 82/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20150927_140634_533_s41.jpg: 160x1184 9 Blesks, Done. (0.016s)
# image 83/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20150927_141134_762_s121.jpg: 160x1184 7 Blesks, Done. (0.020s)
# image 84/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20150927_141134_762_s138.jpg: 160x1184 9 Blesks, Done. (0.015s)
# image 85/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20150927_141634_991_s46.jpg: 160x1184 8 Blesks, Done. (0.015s)
# image 86/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20150927_141634_991_s95.jpg: 160x1184 7 Blesks, Done. (0.016s)
# image 87/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20150927_142135_218_s115.jpg: 160x1184 8 Blesks, Done. (0.015s)
# image 88/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20150927_142135_218_s67.jpg: 160x1184 10 Blesks, Done. (0.017s)
# image 89/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20150927_142135_218_s97.jpg: 160x1184 10 Blesks, Done. (0.014s)
# image 90/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20150927_142635_449_s71.jpg: 160x1184 8 Blesks, Done. (0.017s)
# image 91/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20160802_160438_660_s123.jpg: 160x1184 2 Blesks, Done. (0.014s)
# image 92/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20160802_160938_887_s35.jpg: 160x1184 1 Blesk, Done. (0.016s)
# image 93/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20160802_161939_321_s128.jpg: 160x1184 2 Blesks, Done. (0.016s)
# image 94/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20160802_161939_321_s22.jpg: 160x1184 2 Blesks, Done. (0.014s)
# image 95/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20160802_161939_321_s65.jpg: 160x1184 5 Blesks, Done. (0.014s)
# image 96/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20160802_162439_544_s28.jpg: 160x1184 4 Blesks, Done. (0.020s)
# image 97/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20160802_162939_758_s55.jpg: 160x1184 2 Blesks, Done. (0.014s)
# image 98/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20160802_163439_979_s23.jpg: 160x1184 11 Blesks, Done. (0.016s)
# image 99/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20160802_163940_190_s3.jpg: 160x1184 4 Blesks, Done. (0.016s)
# image 100/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20160802_163940_190_s35.jpg: 160x1184 1 Blesk, Done. (0.016s)
# image 101/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20160802_163940_190_s51.jpg: 160x1184 3 Blesks, Done. (0.016s)
# image 102/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20160802_164440_414_s102.jpg: 160x1184 3 Blesks, Done. (0.017s)
# image 103/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20160802_165440_844_s11.jpg: 160x1184 2 Blesks, Done. (0.018s)
# image 104/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20160802_165440_844_s90.jpg: 160x1184 5 Blesks, Done. (0.018s)
# image 105/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20160807_212510_105_s139.jpg: 160x1184 4 Blesk s chvostikoms, Done. (0.016s)
# image 106/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20160814_145725_103_s121.jpg: 160x1184 4 Blesks, Done. (0.015s)
# image 107/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20160814_145725_103_s18.jpg: 160x1184 2 Blesks, Done. (0.014s)
# image 108/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20160814_150225_332_s28.jpg: 160x1184 3 Blesks, Done. (0.014s)
# image 109/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20160814_150725_573_s108.jpg: 160x1184 2 Blesks, Done. (0.015s)
# image 110/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20160814_152726_476_s58.jpg: 160x1184 3 Blesks, Done. (0.015s)
# image 111/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20160814_153226_709_s79.jpg: 160x1184 2 Blesks, Done. (0.014s)
# image 112/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20160814_153726_935_s109.jpg: 160x1184 6 Blesks, Done. (0.015s)
# image 113/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20160814_153726_935_s19.jpg: 160x1184 6 Blesks, Done. (0.016s)
# image 114/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20160815_202845_581_s46.jpg: 160x1184 6 Blesks, Done. (0.015s)
# image 115/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20160815_202845_581_s79.jpg: 160x1184 6 Blesks, Done. (0.015s)
# image 116/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20160815_203345_809_s1.jpg: 160x1184 6 Blesks, 1 Blesk s chvostikom, Done. (0.016s)
# image 117/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20160815_203345_809_s67.jpg: 160x1184 13 Blesks, 1 Blesk s chvostikom, Done. (0.015s)
# image 118/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20160815_203846_040_s113.jpg: 160x1184 6 Blesks, 6 Blesk s chvostikoms, Done. (0.016s)
# image 119/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20160815_203846_040_s23.jpg: 160x1184 6 Blesks, 2 Blesk s chvostikoms, Done. (0.017s)
# image 120/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20160815_203846_040_s42.jpg: 160x1184 9 Blesks, 3 Blesk s chvostikoms, Done. (0.016s)
# image 121/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20160815_204346_270_s19.jpg: 160x1184 13 Blesks, 2 Blesk s chvostikoms, Done. (0.016s)
# image 122/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20160815_204846_498_s136.jpg: 160x1184 6 Blesks, Done. (0.015s)
# image 123/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20160815_205346_718_s3.jpg: 160x1184 7 Blesks, Done. (0.016s)
# image 124/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20160815_205346_718_s84.jpg: 160x1184 8 Blesks, Done. (0.015s)
# image 125/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20160815_205846_942_s16.jpg: 160x1184 6 Blesks, Done. (0.017s)
# image 126/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20160815_210347_173_s125.jpg: 160x1184 5 Blesks, Done. (0.015s)
# image 127/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20160815_211847_860_s101.jpg: 160x1184 5 Blesks, Done. (0.015s)
# image 128/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20160815_211847_860_s87.jpg: 160x1184 7 Blesks, 1 Blesk s chvostikom, Done. (0.017s)
# image 129/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20160821_184509_734_s103.jpg: 160x1184 12 Blesks, 3 Blesk s chvostikoms, Done. (0.016s)
# image 130/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20160821_184509_734_s106.jpg: 160x1184 6 Blesks, 2 Blesk s chvostikoms, Done. (0.015s)
# image 131/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20160821_184509_734_s124.jpg: 160x1184 7 Blesks, 1 Blesk s chvostikom, Done. (0.015s)
# image 132/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20160821_185510_193_s114.jpg: 160x1184 7 Blesks, 1 Blesk s chvostikom, Done. (0.016s)
# image 133/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20160821_185510_193_s81.jpg: 160x1184 4 Blesks, 2 Blesk s chvostikoms, Done. (0.014s)
# image 134/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20160821_190010_414_s96.jpg: 160x1184 11 Blesks, 1 Blesk s chvostikom, Done. (0.015s)
# image 135/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20160821_193512_001_s140.jpg: 160x1184 14 Blesks, 8 Blesk s chvostikoms, Done. (0.015s)
# image 136/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20160830_191000_059_s134.jpg: 160x1184 16 Blesks, 1 Blesk s chvostikom, Done. (0.016s)
# image 137/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20160830_191000_059_s23.jpg: 160x1184 13 Blesks, 2 Blesk s chvostikoms, Done. (0.016s)
# image 138/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20160830_191500_286_s117.jpg: 160x1184 18 Blesks, 2 Blesk s chvostikoms, Done. (0.013s)
# image 139/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20160830_191500_286_s90.jpg: 160x1184 13 Blesks, 3 Blesk s chvostikoms, Done. (0.016s)
# image 140/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20160830_192000_520_s15.jpg: 160x1184 5 Blesks, 3 Blesk s chvostikoms, Done. (0.016s)
# image 141/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20160830_193000_969_s2.jpg: 160x1184 10 Blesks, 6 Blesk s chvostikoms, Done. (0.014s)
# image 142/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20160830_194501_624_s98.jpg: 160x1184 9 Blesks, 2 Blesk s chvostikoms, Done. (0.016s)
# image 143/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20160830_195001_847_s33.jpg: 160x1184 7 Blesks, 3 Blesk s chvostikoms, Done. (0.015s)
# image 144/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20170702_161620_729_s119.jpg: 160x1184 1 Blesk, Done. (0.019s)
# image 145/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20170702_161620_729_s48.jpg: 160x1184 1 Blesk, Done. (0.014s)
# image 146/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20170702_161620_729_s98.jpg: 160x1184 2 Blesks, Done. (0.015s)
# image 147/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20170702_164121_739_s52.jpg: 160x1184 9 Blesks, Done. (0.015s)
# image 148/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20170702_164621_934_s16.jpg: 160x1184 6 Blesks, Done. (0.015s)
# image 149/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20170702_164621_934_s99.jpg: 160x1184 5 Blesks, Done. (0.016s)
# image 150/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20170707_230135_323_s29.jpg: 160x1184 3 Blesk s chvostikoms, Done. (0.016s)
# image 151/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20170707_230135_323_s9.jpg: 160x1184 5 Blesks, 1 Blesk s chvostikom, Done. (0.017s)
# image 152/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20170707_230635_533_s53.jpg: 160x1184 3 Blesk s chvostikoms, Done. (0.015s)
# image 153/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20170707_230635_533_s83.jpg: 160x1184 2 Blesks, 1 Blesk s chvostikom, Done. (0.016s)
# image 154/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20170707_231135_735_s31.jpg: 160x1184 2 Blesks, 4 Blesk s chvostikoms, Done. (0.014s)
# image 155/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20170707_231135_735_s65.jpg: 160x1184 1 Blesk, 1 Blesk s chvostikom, Done. (0.016s)
# image 156/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20170707_231635_946_s129.jpg: 160x1184 1 Blesk, 2 Blesk s chvostikoms, Done. (0.015s)
# image 157/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20170707_232136_161_s124.jpg: 160x1184 3 Blesks, 4 Blesk s chvostikoms, Done. (0.016s)
# image 158/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20170707_233136_589_s45.jpg: 160x1184 5 Blesks, 5 Blesk s chvostikoms, Done. (0.016s)
# image 159/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20170707_233636_813_s142.jpg: 160x1184 3 Blesks, 2 Blesk s chvostikoms, Done. (0.015s)
# image 160/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20170707_234137_018_s6.jpg: 160x1184 6 Blesks, 3 Blesk s chvostikoms, Done. (0.016s)
# image 161/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20170707_234637_231_s41.jpg: 160x1184 8 Blesks, 3 Blesk s chvostikoms, Done. (0.015s)
# image 162/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20170707_235637_636_s85.jpg: 160x1184 4 Blesks, 1 Blesk s chvostikom, Done. (0.016s)
# image 163/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20170714_153824_509_s124.jpg: 160x1184 5 Blesks, Done. (0.016s)
# image 164/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20170714_153824_509_s134.jpg: 160x1184 3 Blesks, Done. (0.016s)
# image 165/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20170714_155325_160_s107.jpg: 160x1184 9 Blesks, Done. (0.013s)
# image 166/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20170714_155325_160_s90.jpg: 160x1184 3 Blesks, Done. (0.014s)
# image 167/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20170714_155825_392_s62.jpg: 160x1184 7 Blesks, Done. (0.015s)
# image 168/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20170715_121417_713_s62.jpg: 160x1184 6 Blesks, Done. (0.017s)
# image 169/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20170715_121917_931_s35.jpg: 160x1184 4 Blesks, Done. (0.016s)
# image 170/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20170715_121917_931_s45.jpg: 160x1184 1 Blesk, Done. (0.016s)
# image 171/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20170715_123918_771_s140.jpg: 160x1184 8 Blesks, Done. (0.015s)
# image 172/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20170715_123918_771_s48.jpg: 160x1184 3 Blesks, Done. (0.016s)
# image 173/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20170715_125419_435_s68.jpg: 160x1184 8 Blesks, Done. (0.014s)
# image 174/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20170715_125419_435_s86.jpg: 160x1184 4 Blesks, Done. (0.016s)
# image 175/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20170715_125419_435_s94.jpg: 160x1184 4 Blesks, 1 Blesk s chvostikom, Done. (0.016s)
# image 176/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20170715_125919_649_s124.jpg: 160x1184 7 Blesks, Done. (0.016s)
# image 177/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20170715_125919_649_s76.jpg: 160x1184 3 Blesks, Done. (0.014s)
# image 178/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20170715_130419_865_s144.jpg: 160x1184 8 Blesks, Done. (0.013s)
# image 179/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20170715_130920_071_s111.jpg: 160x1184 8 Blesks, Done. (0.014s)
# image 180/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20170715_130920_071_s44.jpg: 160x1184 11 Blesks, Done. (0.022s)
# image 181/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20170715_130920_071_s7.jpg: 160x1184 10 Blesks, Done. (0.016s)
# image 182/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20170721_215037_895_s10.jpg: 160x1184 11 Blesks, 3 Blesk s chvostikoms, Done. (0.015s)
# image 183/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20170721_221038_676_s133.jpg: 160x1184 20 Blesks, 2 Blesk s chvostikoms, Done. (0.016s)
# image 184/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20170721_222039_070_s139.jpg: 160x1184 9 Blesks, 5 Blesk s chvostikoms, Done. (0.016s)
# image 185/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20170721_222039_070_s46.jpg: 160x1184 7 Blesks, 2 Blesk s chvostikoms, Done. (0.014s)
# image 186/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20170721_222039_070_s92.jpg: 160x1184 9 Blesks, 2 Blesk s chvostikoms, Done. (0.015s)
# image 187/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20170721_222039_070_s99.jpg: 160x1184 9 Blesks, 1 Blesk s chvostikom, Done. (0.015s)
# image 188/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20170721_222539_271_s107.jpg: 160x1184 13 Blesks, Done. (0.015s)
# image 189/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20170721_222539_271_s15.jpg: 160x1184 10 Blesks, 1 Blesk s chvostikom, Done. (0.016s)
# image 190/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20170721_223539_659_s139.jpg: 160x1184 14 Blesks, 1 Blesk s chvostikom, Done. (0.016s)
# image 191/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20170721_223539_659_s67.jpg: 160x1184 8 Blesks, 3 Blesk s chvostikoms, Done. (0.017s)
# image 192/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20170721_224540_057_s112.jpg: 160x1184 9 Blesks, 3 Blesk s chvostikoms, Done. (0.019s)
# image 193/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20170730_170406_445_s26.jpg: 160x1184 10 Blesks, Done. (0.015s)
# image 194/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20170730_170406_445_s65.jpg: 160x1184 7 Blesks, Done. (0.015s)
# image 195/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20170730_171406_868_s8.jpg: 160x1184 15 Blesks, Done. (0.015s)
# image 196/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20170730_172407_273_s36.jpg: 160x1184 13 Blesks, Done. (0.016s)
# image 197/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20170730_172407_273_s77.jpg: 160x1184 11 Blesks, Done. (0.017s)
# image 198/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20170730_172907_467_s88.jpg: 160x1184 21 Blesks, Done. (0.015s)
# image 199/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20180602_211730_150_s120.jpg: 160x1184 2 Blesks, 2 Blesk s chvostikoms, Done. (0.016s)
# image 200/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20180602_212730_544_s102.jpg: 160x1184 3 Blesks, 4 Blesk s chvostikoms, Done. (0.015s)
# image 201/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20180602_212730_544_s103.jpg: 160x1184 1 Blesk, 2 Blesk s chvostikoms, Done. (0.016s)
# image 202/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20180607_190213_819_s69.jpg: 160x1184 6 Blesks, Done. (0.016s)
# image 203/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20180607_192214_623_s128.jpg: 160x1184 11 Blesks, Done. (0.016s)
# image 204/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20180607_192214_623_s140.jpg: 160x1184 9 Blesks, Done. (0.014s)
# image 205/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20180607_192214_623_s26.jpg: 160x1184 8 Blesks, 1 Blesk s chvostikom, Done. (0.015s)
# image 206/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20180607_192214_623_s60.jpg: 160x1184 11 Blesks, 2 Blesk s chvostikoms, Done. (0.015s)
# image 207/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20180607_192714_820_s16.jpg: 160x1184 10 Blesks, 1 Blesk s chvostikom, Done. (0.014s)
# image 208/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20180607_192714_820_s70.jpg: 160x1184 13 Blesks, 1 Blesk s chvostikom, Done. (0.015s)
# image 209/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20180607_193215_024_s131.jpg: 160x1184 5 Blesks, 3 Blesk s chvostikoms, Done. (0.015s)
# image 210/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20180607_193215_024_s77.jpg: 160x1184 8 Blesks, 1 Blesk s chvostikom, Done. (0.015s)
# image 211/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20180607_193215_024_s81.jpg: 160x1184 12 Blesks, 3 Blesk s chvostikoms, Done. (0.015s)
# image 212/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20180607_193715_226_s111.jpg: 160x1184 7 Blesks, 1 Blesk s chvostikom, Done. (0.016s)
# image 213/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20180607_194215_422_s125.jpg: 160x1184 10 Blesks, Done. (0.014s)
# image 214/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20180607_194215_422_s134.jpg: 160x1184 10 Blesks, Done. (0.018s)
# image 215/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20180607_194215_422_s43.jpg: 160x1184 5 Blesks, 2 Blesk s chvostikoms, Done. (0.016s)
# image 216/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20180607_194215_422_s59.jpg: 160x1184 10 Blesks, 3 Blesk s chvostikoms, Done. (0.014s)
# image 217/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20180607_194215_422_s68.jpg: 160x1184 11 Blesks, 1 Blesk s chvostikom, Done. (0.015s)
# image 218/218 /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/yolo/test_img/ch1_20180607_195716_031_s91.jpg: 160x1184 12 Blesks, Done. (0.016s)
# Results saved to runs/detect/exp2
# 218 labels saved to runs/detect/exp2/labels
# Done. (18.015s)

# %% [markdown]
# ## Spustenie vyhodnotenia metrík neurónovej siete
#
# ### Vstupy
# test.py: cesta k súboru test.py<br>
# weights: parameter obsahujúci cestu k váham, pomocou ktorých chceme test vykonať<br>
# data: cesta k súboru yaml, ktorý obsahuje cesty ku train, text a val množinám<br>
# img: veľkosť obrázka, na ktorom bude trénovanie prebiehať v pixeloch
# batch-size: hodnota batch-size pre test<br>
# iou: hodnota thresholdu IoU<br>
# conf: hodnota confidence thresholdu<br>
# task: množina, na ktorej sa bude test vykonávať (možno vybrať z train, test a val)

# %%
# !python yolo/test.py --weights ./yolo/runs/train/exp17/weights/best.pt --data ./yolo/data/blesky.yaml --img 1184 --batch-size 4 --iou 0.45 --conf 0.3 --task 'test'
# Out:
# Namespace(augment=False, batch_size=4, conf_thres=0.3, data='./yolo/data/blesky.yaml', device='', exist_ok=False, img_size=1184, iou_thres=0.45, name='exp', project='runs/test', save_conf=False, save_hybrid=False, save_json=False, save_txt=False, single_cls=False, task='test', verbose=False, weights=['./yolo/runs/train/exp17/weights/best.pt'])
# requirements: /home/jovyan/data/lightning/adrian/pics/BP_Kundrat_Adrian/requirements.txt not found, check failed.
# YOLOv5 🚀 v5.0-97-gffb47ff torch 1.7.0 CUDA:0 (Quadro RTX 4000, 7982.3125MB)
#
# Fusing layers...
# Model Summary: 224 layers, 7056607 parameters, 0 gradients
# test: Scanning 'yolo/data/Test_batch.cache' images and labels... 218 found, 0 mi
#                Class      Images      Labels           P           R     mAP@.45
#                Class      Images      Labels           P           R     mAP@.45
#                Class      Images      Labels           P           R     mAP@.45
#                Class      Images      Labels           P           R     mAP@.45
#                Class      Images      Labels           P           R     mAP@.45
#                Class      Images      Labels           P           R     mAP@.45
#                Class      Images      Labels           P           R     mAP@.45
#                Class      Images      Labels           P           R     mAP@.45
#                Class      Images      Labels           P           R     mAP@.45
#                Class      Images      Labels           P           R     mAP@.45
#                Class      Images      Labels           P           R     mAP@.45
#                Class      Images      Labels           P           R     mAP@.45
#                Class      Images      Labels           P           R     mAP@.45
#                Class      Images      Labels           P           R     mAP@.45
#                Class      Images      Labels           P           R     mAP@.45
#                Class      Images      Labels           P           R     mAP@.45
#                Class      Images      Labels           P           R     mAP@.45
#                Class      Images      Labels           P           R     mAP@.45
#                Class      Images      Labels           P           R     mAP@.45
#                Class      Images      Labels           P           R     mAP@.45
#                Class      Images      Labels           P           R     mAP@.45
#                Class      Images      Labels           P           R     mAP@.45
#                Class      Images      Labels           P           R     mAP@.45
#                Class      Images      Labels           P           R     mAP@.45
#                Class      Images      Labels           P           R     mAP@.45
# test: Scanning 'yolo/data/Test_batch.cache' images and labels... 218 found, 0 mi
#                  all         218        2135       0.733       0.745        0.68       0.362
#                Blesk         218        1890       0.808       0.796       0.738       0.362
#   Blesk s chvostikom         218         245       0.659       0.694       0.621       0.363
# Speed: 3.3/1.4/4.7 ms inference/NMS/total per 1184x1184 image at batch-size 4
# ####################################################
# [[       1501         104         288]
#  [         24         135         103]
#  [        365           6           0]]
# ####################################################
# Results saved to runs/test/exp

# %% [markdown]
# ## Vytvorenie tabuľky z výstupov neurónovej siete
#
# route: názov priečnika obsahujúceho detekciu<br>
# imagePath: cesta k priečinku, v ktorom sa nachádza množina obrázkov použitá pri detekcii<br>
# rootPath: cesta k priečinku obsahujúcemu textové súbory z detekcie<br>
# path: cesta pre uloženie výstupného súboru

# %%
route="exp"
imagePath="yolo/test_img"
rootPath = r"runs/detect/" + route + "/labels"
path = "files"

# %%
imageNR=1

with open(os.path.join(path, "output" + route + ".csv"), "w") as outputCsv:    
    fieldnamesOutput = ['image','event', 'date', 'second', 'milisecond', 'tweek', 'f_min<2kHz', 'confidence']
    tableWriter = csv.DictWriter(outputCsv, fieldnames=fieldnamesOutput, delimiter=',')
    tableWriter.writeheader()
    
    for root, dirs, files in os.walk(rootPath):
        for file in files:
            with open(os.path.join(root, file), "r") as csv_file:
                reader = csv.reader(csv_file, delimiter=' ')
                sortedlist = sorted(reader, key=operator.itemgetter(1))
            with open(os.path.join(root, file), "w") as csv_file1:
                writer = csv.writer(csv_file1, delimiter=' ')
                writer.writerows(sortedlist)

            with open(os.path.join(root, file), "r") as coordFile:

                fieldnamesCoords = ['label','x', 'y', 'width', 'height', 'conf']
                eventNR=1
                coordReader = csv.DictReader(coordFile, fieldnames=fieldnamesCoords, delimiter=' ')
                try:
                    img = Image.open(os.path.join(imagePath, file.split(".")[0]+".jpg"))
                except:
                    break
                w, h = img.size
                widthms=w/1000

                for row in coordReader:
                    widthCoord=round(float(row['width'])*w)
                    xCoord=round((float(row['x'])*w)-(float(widthCoord)/2))
                    im = img.crop((xCoord, 0, xCoord+widthCoord, 162)).save(os.path.join(root, "1.jpg"))
                    red = imread(os.path.join(root, "1.jpg"))[:, :, 0]
                    os.remove(os.path.join(root, "1.jpg"))

                    red=np.delete(red,len(red)-1,0)
                    red=np.delete(red,len(red)-1,0)

                    transposered=np.transpose(red)

                    middle=0
                    indexOfMid=0
                    currentIndex=1
                    for i in transposered:
                        if sum(i) > middle:
                            middle=sum(i)
                            indexOfMid=currentIndex
                        currentIndex+=1

                    milsec=round((indexOfMid+xCoord)/widthms)

                    j=0
                    celyobr=0
                    konec=0
                    while(j<160):
                        celyobr+=sum(red[j])
                        if j>138:
                            konec+=sum(red[j])

                        j+=1

                    if (float((konec*100)/celyobr))>9.5:
                        vysledok=1
                    else: vysledok=0
                    tableWriter.writerow({
                        'image':imageNR, 
                        'event':eventNR, 
                        'date':file[4:19], 
                        'second':file[file.find("s")+1:file.find(".txt")], 
                        'milisecond':milsec, 
                        'tweek':row['label'], 
                        'f_min<2kHz':vysledok,
                        'confidence':round(float(row['conf']),3)})
                    eventNR+=1
                    # print(row)

                imageNR+=1
